# %%
import pandas as pd

# %%
raw_data_url = r"../data/aircraft_logs_data.xlsx"
data = pd.read_excel(raw_data_url)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Aircraft_ID                     501 non-null    str
#  1   Aircraft_Model                  501 non-null    str
#  2   Engine_Model                    501 non-null    str
#  3   Airport_Code                    501 non-null    str
#  4   Flight_Cycle (cycles)           501 non-null    int64
#  5   Flight_Hours (hrs)              501 non-null    float64
#  6   Cycles_Since_Overhaul (cycles)  501 non-null    int64
#  7   Last_Maintenance_Date           501 non-null    str
#  8   Ambient_Temperature (°C)        501 non-null    float64
#  9   Humidity (%)                    501 non-null    int64
#  10  Outside_Air_Temperature (°C)    501 non-null    float64
#  11  Engine_Temperature (°C)         501 non-null    float64
# ...

# %%
data.head()
# Out:
#   Aircraft_ID Aircraft_Model Engine_Model Airport_Code  Flight_Cycle (cycles)  \
# 0     AIR-001        A320neo  CFM LEAP-1A          JFK                      1
# 1     AIR-001        A320neo  CFM LEAP-1A          DXB                      2
# 2     AIR-001        A320neo  CFM LEAP-1A          DEL                      3
# 3     AIR-001        A320neo  CFM LEAP-1A          CDG                      4
# 4     AIR-001        A320neo  CFM LEAP-1A          CDG                      5
#
#    Flight_Hours (hrs)  Cycles_Since_Overhaul (cycles) Last_Maintenance_Date  \
# 0                 3.0                               1            2026-01-04
# 1                 7.8                               2            2026-01-07
# 2                10.1                               3            2026-01-10
# 3                12.9                               4            2026-01-13
# 4                16.1                               5            2026-01-16
#
# ...

# %%
print(pd.ExcelFile(raw_data_url).sheet_names)
# Out:
# ['AircraftMaintenanceData']
